# %% [markdown]
# # Build graph usinf Tf operation

# %%
import tensorflow as tf
tf.set_random_seed(777)

# %%
x_train =[1,2,3]
y_train =[1,2,3]

# %% [markdown]
# * Variable 은 변수와는 다른 개념으로 텐서플로우가 자체적으로 변경시키는 값으로 보면됨.

# %% [markdown]
# * shape은 값이 하나인(rank가 1인) 1차원 배열을 의미

# %%
W = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bias')

# %%
hypothesis = x_train *W+b

# %%
cost = tf.reduce_mean(tf.square(hypothesis-y_train))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate =0.01)
train =  optimizer.minimize(cost)

# %% [markdown]
# # Run/update graph and get result

# %%
sess  =tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(2001):
    sess.run(train)
    if step % 20 ==0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 0.4050336 [0.6214727] [0.20071684]
# 20 0.015884057 [0.84785306] [0.28304338]
# 40 0.01123489 [0.8748653] [0.27847868]
# 60 0.010174771 [0.88263744] [0.26622316]
# 80 0.00924063 [0.8883331] [0.25379083]
# 100 0.0083924765 [0.8935982] [0.24187112]
# 120 0.007622188 [0.8986004] [0.23050478]
# 140 0.0069225957 [0.90336597] [0.21967195]
# 160 0.0062872116 [0.90790725] [0.20934817]
# 180 0.0057101394 [0.9122354] [0.19950959]
# 200 0.0051860455 [0.91635996] [0.19013342]
# 220 0.0047100517 [0.9202907] [0.1811979]
# 240 0.004277746 [0.92403674] [0.17268232]
# 260 0.0038851209 [0.92760676] [0.16456686]
# 280 0.0035285268 [0.93100905] [0.15683278]
# 300 0.0032046624 [0.9342513] [0.1494622]
# 320 0.002910529 [0.9373412] [0.14243805]
# 340 0.0026433838 [0.940286] [0.135744]
# 360 0.002400771 [0.9430923] [0.12936458]
# 380 0.0021804152 [0.94576675] [0.1232849]
# 400 0.0019802863 [0.94831556] [0.11749096]
# 420 0.0017985346 [0.9507445] [0.11196929]
# 440 0.0016334485 [0.9530593] [0.10670715]
# ...

# %% [markdown]
# # placeholders

# %%
W = tf.Variable(tf.random_normal([1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")
X = tf.placeholder(tf.float32, shape=[None])
Y = tf.placeholder(tf.float32, shape=[None])

# %%
hypothesis = X * W + b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
train = tf.train.GradientDescentOptimizer(learning_rate=0.01).minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(2001):
    _, cost_val, W_val, b_val = sess.run([train, cost, W, b],feed_dict={X: [1, 2, 3, 4, 5], Y: [2.1, 3.1, 4.1, 5.1, 6.1]},)
    if step % 20 == 0:
            print(step, cost_val, W_val, b_val)
# Out:
# 0 1.873777 [1.5267844] [0.29167318]
# 20 0.12573358 [1.2306699] [0.27214792]
# 40 0.109773204 [1.2143815] [0.32603726]
# 60 0.09586576 [1.2003361] [0.37672323]
# 80 0.08372031 [1.1872158] [0.42409125]
# 100 0.073113576 [1.1749549] [0.4683571]
# 120 0.06385061 [1.163497] [0.50972384]
# 140 0.055761266 [1.1527895] [0.54838145]
# 160 0.048696727 [1.142783] [0.58450747]
# 180 0.0425272 [1.1334321] [0.6182675]
# 200 0.03713929 [1.1246936] [0.64981645]
# 220 0.03243402 [1.1165273] [0.6792993]
# 240 0.028324908 [1.1088959] [0.7068513]
# 260 0.024736343 [1.1017641] [0.73259896]
# 280 0.02160241 [1.0950996] [0.7566604]
# 300 0.018865542 [1.0888714] [0.779146]
# 320 0.016475447 [1.0830511] [0.800159]
# 340 0.014388107 [1.0776119] [0.8197958]
# 360 0.0125652505 [1.0725293] [0.8381465]
# 380 0.0109733585 [1.0677792] [0.8552954]
# 400 0.009583093 [1.0633403] [0.8713213]
# 420 0.008369001 [1.0591922] [0.8862975]
# 440 0.007308717 [1.0553156] [0.9002931]
# 460 0.0063827382 [1.0516931] [0.9133721]
# ...

# %%
print(sess.run(hypothesis, feed_dict={X:[5]}))
print(sess.run(hypothesis, feed_dict={X:[2.5]}))
print(sess.run(hypothesis, feed_dict={X:[1.5,3.5]}))
# Out:
# [6.1003914]
# [3.5996883]
# [2.5994072 4.599969 ]
