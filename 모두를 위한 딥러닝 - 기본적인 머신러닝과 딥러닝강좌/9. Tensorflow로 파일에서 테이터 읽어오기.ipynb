# %%
data = open('data-01-test-score.csv','w',encoding='utf8')
print('# EXAM1, EXAM2, EXAM3, FINAL\n73,80,75,152\n93,88,93,185\n88,91,90,180\n96,98,100,196\n73,66,70,142\n53,46,55,101', file= data)
data.close()

# %%
import numpy as np

# %%
xy = np.loadtxt('data-01-test-score.csv', delimiter=',',dtype=np.float32)
x_data = xy[:,0:-1]
y_data = xy[:,[-1]]

# %%
print(x_data.shape, x_data, len(x_data))
print(y_data.shape, y_data)
# Out:
# (6, 3) [[ 73.  80.  75.]
#  [ 93.  88.  93.]
#  [ 88.  91.  90.]
#  [ 96.  98. 100.]
#  [ 73.  66.  70.]
#  [ 53.  46.  55.]] 6
# (6, 1) [[152.]
#  [185.]
#  [180.]
#  [196.]
#  [142.]
#  [101.]]

# %% [markdown]
# *************************************************************

# %% [markdown]
# *************************************************************

# %%
import tensorflow as tf
import numpy as np

# %%
tf.set_random_seed(777)

# %%
xy = np.loadtxt('data-01-test-score.csv', delimiter=',',dtype=np.float32)
x_data = xy[:,0:-1]
y_data = xy[:,[-1]]

# %% [markdown]
# * make sure the shape and data are ok

# %%
print(x_data.shape, x_data, len(x_data))
print(y_data.shape, y_data)
# Out:
# (6, 3) [[ 73.  80.  75.]
#  [ 93.  88.  93.]
#  [ 88.  91.  90.]
#  [ 96.  98. 100.]
#  [ 73.  66.  70.]
#  [ 53.  46.  55.]] 6
# (6, 1) [[152.]
#  [185.]
#  [180.]
#  [196.]
#  [142.]
#  [101.]]

# %% [markdown]
# * placeholder for a tensor that will bw always fed

# %%
X = tf.placeholder(tf.float32, shape=[None,3])
Y = tf.placeholder(tf.float32, shape=[None,1])

# %%
W = tf.Variable(tf.random_normal([3,1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# %% [markdown]
# * Hypothisis

# %%
hypothesis = tf.matmul(X,W) + b

# %% [markdown]
# * Simplified cost/loss function

# %%
cost = tf.reduce_mean(tf.square(hypothesis-Y))

# %% [markdown]
# * mintimize

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# %% [markdown]
# * Launch the graph in a session

# %%
sess = tf.Session()

# %% [markdown]
# * Initializes global variable in the graph

# %%
sess.run(tf.global_variables_initializer())

# %% [markdown]
# * Set up feeg_dict variables inside the loop

# %%
for step in range(2001):
    cost_val, hy_val,_=sess.run(
    [cost, hypothesis, train],
    feed_dict={X:x_data, Y:y_data})
    if step % 10 ==0:
        print(step, 'Cost', cost_val, '\nprediction\n', hy_val)
# Out:
# 0 Cost 20386.096
# prediction
#  [[22.048063 ]
#  [21.619787 ]
#  [23.29399  ]
#  [22.293005 ]
#  [18.633902 ]
#  [ 7.2669735]]
# 10 Cost 6.656916
# prediction
#  [[155.22491]
#  [181.74565]
#  [180.4548 ]
#  [194.08394]
#  [140.77455]
#  [ 97.31615]]
# 20 Cost 5.672014
# prediction
#  [[156.12535]
#  [182.84602]
#  [181.52473]
#  [195.25653]
#  [141.61649]
#  [ 97.94234]]
# 30 Cost 5.640638
# prediction
#  [[156.12115]
#  [182.85875]
#  [181.52715]
#  [195.26219]
#  [141.6288 ]
#  [ 97.95687]]
# 40 Cost 5.6094775
# prediction
#  [[156.1108 ]
#  [182.86401]
#  [181.52226]
#  [195.25989]
#  [141.6354 ]
#  [ 97.96721]]
# 50 Cost 5.57855
# prediction
#  [[156.10045]
#  [182.86922]
#  [181.51733]
#  [195.25757]
#  [141.64197]
#  [ 97.97747]]
# 60 Cost 5.547812
# prediction
#  [[156.0901  ]
#  [182.87437 ]
#  [181.5124  ]
#  [195.25523 ]
#  [141.64848 ]
#  [ 97.987686]]
# 70 Cost 5.5173078
# prediction
#  [[156.07982]
#  [182.87953]
#  [181.50754]
#  [195.2529 ]
#  [141.655  ]
#  [ 97.99789]]
# 80 Cost 5.4869876
# prediction
#  [[156.06958 ]
#  [182.8847  ]
#  [181.50269 ]
#  [195.25058 ]
#  [141.66148 ]
#  [ 98.008064]]
# 90 Cost 5.4568543
# prediction
#  [[156.05934]
#  [182.88982]
#  [181.49782]
#  [195.24828]
#  [141.66795]
#  [ 98.01819]]
# 100 Cost 5.42699
# prediction
#  [[156.04916]
#  [182.8949 ]
#  [181.49297]
#  [195.24596]
#  [141.67438]
#  [ 98.02827]]
# 110 Cost 5.3972297
# prediction
#  [[156.039  ]
#  [182.90001]
#  [181.48817]
#  [195.24371]
#  [141.68079]
#  [ 98.03835]]
# 120 Cost 5.3677144
# prediction
#  [[156.02887]
#  [182.90506]
#  [181.48335]
#  [195.24141]
#  [141.68718]
#  [ 98.04838]]
# 130 Cost 5.338426
# prediction
#  [[156.01881]
#  [182.91013]
#  [181.47856]
#  [195.23914]
#  [141.69353]
#  [ 98.05838]]
# 140 Cost 5.3093343
# prediction
#  [[156.00877 ]
#  [182.91516 ]
#  [181.47382 ]
#  [195.23686 ]
#  [141.69989 ]
#  [ 98.068344]]
# 150 Cost 5.2803745
# prediction
#  [[155.99875]
#  [182.9202 ]
#  [181.46904]
#  [195.23462]
#  [141.70619]
#  [ 98.07828]]
# 160 Cost 5.2516747
# prediction
#  [[155.98877]
#  [182.92519]
#  [181.4643 ]
#  [195.23236]
#  [141.7125 ]
#  [ 98.08816]]
# 170 Cost 5.2231474
# prediction
#  [[155.97882]
#  [182.93016]
#  [181.4596 ]
#  [195.23013]
#  [141.71877]
#  [ 98.09803]]
# 180 Cost 5.1947837
# prediction
#  [[155.9689 ]
#  [182.93513]
#  [181.45488]
#  [195.22789]
#  [141.72502]
#  [ 98.10787]]
# 190 Cost 5.166611
# prediction
#  [[155.95901]
#  [182.9401 ]
#  [181.45018]
#  [195.22568]
#  [141.73126]
#  [ 98.11767]]
# 200 Cost 5.138652
# prediction
#  [[155.94916]
#  [182.945  ]
#  [181.4455 ]
#  [195.22345]
#  [141.73743]
#  [ 98.12743]]
# 210 Cost 5.1108694
# prediction
#  [[155.93935]
#  [182.94994]
#  [181.44084]
#  [195.22125]
#  [141.74362]
#  [ 98.13717]]
# 220 Cost 5.08328
# prediction
#  [[155.92957]
#  [182.95482]
#  [181.43619]
#  [195.21904]
#  [141.74979]
#  [ 98.14688]]
# 230 Cost 5.055857
# prediction
#  [[155.91982 ]
#  [182.9597  ]
#  [181.43155 ]
#  [195.21687 ]
#  [141.75592 ]
#  [ 98.156555]]
# 240 Cost 5.028644
# prediction
#  [[155.9101 ]
#  [182.96457]
#  [181.42694]
#  [195.21468]
#  [141.76202]
#  [ 98.16618]]
# 250 Cost 5.00161
# prediction
#  [[155.90042 ]
#  [182.9694  ]
#  [181.42235 ]
#  [195.21251 ]
#  [141.76813 ]
#  [ 98.175804]]
# 260 Cost 4.9747653
# prediction
#  [[155.89078]
#  [182.97424]
#  [181.41777]
#  [195.21034]
#  [141.7742 ]
#  [ 98.18537]]
# 270 Cost 4.9480753
# prediction
#  [[155.88115]
#  [182.97903]
#  [181.41321]
#  [195.20819]
#  [141.78023]
#  [ 98.19493]]
# 280 Cost 4.921545
# prediction
#  [[155.87157]
#  [182.98386]
#  [181.40865]
#  [195.20605]
#  [141.78625]
#  [ 98.20445]]
# 290 Cost 4.895219
# prediction
#  [[155.862  ]
#  [182.98862]
#  [181.4041 ]
#  [195.2039 ]
#  [141.79227]
#  [ 98.21393]]
# 300 Cost 4.86909
# prediction
#  [[155.8525 ]
#  [182.99338]
#  [181.39958]
#  [195.20178]
#  [141.79823]
#  [ 98.22338]]
# 310 Cost 4.8430905
# prediction
#  [[155.84299]
#  [182.99812]
#  [181.39508]
#  [195.19968]
#  [141.8042 ]
#  [ 98.2328 ]]
# 320 Cost 4.8173175
# prediction
#  [[155.83354 ]
#  [183.00285 ]
#  [181.39061 ]
#  [195.19754 ]
#  [141.81015 ]
#  [ 98.242195]]
# 330 Cost 4.7916617
# prediction
#  [[155.82411]
#  [183.00758]
#  [181.38612]
#  [195.19545]
#  [141.81606]
#  [ 98.25156]]
# 340 Cost 4.7662063
# prediction
#  [[155.81473 ]
#  [183.01228 ]
#  [181.38167 ]
#  [195.19336 ]
#  [141.82196 ]
#  [ 98.260895]]
# 350 Cost 4.740933
# prediction
#  [[155.80536]
#  [183.01694]
#  [181.37721]
#  [195.19125]
#  [141.82784]
#  [ 98.27019]]
# 360 Cost 4.7158275
# prediction
#  [[155.79604]
#  [183.0216 ]
#  [181.3728 ]
#  [195.18918]
#  [141.83368]
#  [ 98.27946]]
# 370 Cost 4.690857
# prediction
#  [[155.78673]
#  [183.02626]
#  [181.36838]
#  [195.1871 ]
#  [141.83951]
#  [ 98.2887 ]]
# 380 Cost 4.6660757
# prediction
#  [[155.77747 ]
#  [183.0309  ]
#  [181.36398 ]
#  [195.18504 ]
#  [141.84532 ]
#  [ 98.297905]]
# 390 Cost 4.6414685
# prediction
#  [[155.76823]
#  [183.0355 ]
#  [181.3596 ]
#  [195.183  ]
#  [141.85109]
#  [ 98.30708]]
# 400 Cost 4.617021
# prediction
#  [[155.75905]
#  [183.04015]
#  [181.35526]
#  [195.18095]
#  [141.85689]
#  [ 98.31623]]
# 410 Cost 4.5927396
# prediction
#  [[155.74986]
#  [183.04471]
#  [181.35089]
#  [195.1789 ]
#  [141.86261]
#  [ 98.32534]]
# 420 Cost 4.568603
# prediction
#  [[155.7407 ]
#  [183.04927]
#  [181.34654]
#  [195.17686]
#  [141.86835]
#  [ 98.33442]]
# 430 Cost 4.544657
# prediction
#  [[155.73161 ]
#  [183.05382 ]
#  [181.34221 ]
#  [195.17485 ]
#  [141.87405 ]
#  [ 98.343475]]
# 440 Cost 4.5208507
# prediction
#  [[155.72253 ]
#  [183.05835 ]
#  [181.3379  ]
#  [195.17284 ]
#  [141.8797  ]
#  [ 98.352516]]
# 450 Cost 4.49721
# prediction
#  [[155.71349]
#  [183.06287]
#  [181.33362]
#  [195.17082]
#  [141.88538]
#  [ 98.36152]]
# 460 Cost 4.473733
# prediction
#  [[155.70447]
#  [183.06737]
#  [181.32935]
#  [195.16882]
#  [141.89102]
#  [ 98.37048]]
# 470 Cost 4.450393
# prediction
#  [[155.69548 ]
#  [183.07187 ]
#  [181.32507 ]
#  [195.16682 ]
#  [141.89665 ]
#  [ 98.379425]]
# 480 Cost 4.4272194
# prediction
#  [[155.68652 ]
#  [183.07634 ]
#  [181.32082 ]
#  [195.16484 ]
#  [141.90224 ]
#  [ 98.388336]]
# 490 Cost 4.404185
# prediction
#  [[155.67758]
#  [183.0808 ]
#  [181.31657]
#  [195.16286]
#  [141.9078 ]
#  [ 98.39722]]
# 500 Cost 4.3813567
# prediction
#  [[155.66869]
#  [183.08522]
#  [181.31236]
#  [195.16087]
#  [141.91336]
#  [ 98.40605]]
# 510 Cost 4.358613
# prediction
#  [[155.65982]
#  [183.08966]
#  [181.30814]
#  [195.15894]
#  [141.91891]
#  [ 98.41489]]
# 520 Cost 4.336069
# prediction
#  [[155.65099 ]
#  [183.09407 ]
#  [181.30397 ]
#  [195.157   ]
#  [141.92442 ]
#  [ 98.423676]]
# 530 Cost 4.3136463
# prediction
#  [[155.64218]
#  [183.09848]
#  [181.29977]
#  [195.15503]
#  [141.92993]
#  [ 98.43245]]
# 540 Cost 4.2913966
# prediction
#  [[155.63339]
#  [183.10284]
#  [181.29561]
#  [195.15309]
#  [141.9354 ]
#  [ 98.44117]]
# 550 Cost 4.269281
# prediction
#  [[155.62465]
#  [183.10722]
#  [181.29146]
#  [195.15115]
#  [141.94086]
#  [ 98.44988]]
# 560 Cost 4.2472987
# prediction
#  [[155.61592 ]
#  [183.11157 ]
#  [181.28731 ]
#  [195.14923 ]
#  [141.94629 ]
#  [ 98.458565]]
# 570 Cost 4.2255073
# prediction
#  [[155.60725 ]
#  [183.1159  ]
#  [181.2832  ]
#  [195.14732 ]
#  [141.95172 ]
#  [ 98.467224]]
# 580 Cost 4.2038274
# prediction
#  [[155.59859 ]
#  [183.12022 ]
#  [181.2791  ]
#  [195.14543 ]
#  [141.9571  ]
#  [ 98.475845]]
# 590 Cost 4.182307
# prediction
#  [[155.58995 ]
#  [183.12453 ]
#  [181.27501 ]
#  [195.14351 ]
#  [141.96248 ]
#  [ 98.484436]]
# 600 Cost 4.1609216
# prediction
#  [[155.58134 ]
#  [183.1288  ]
#  [181.2709  ]
#  [195.1416  ]
#  [141.96783 ]
#  [ 98.493004]]
# 610 Cost 4.139672
# prediction
#  [[155.57277]
#  [183.13309]
#  [181.26685]
#  [195.13972]
#  [141.97318]
#  [ 98.50154]]
# 620 Cost 4.1185737
# prediction
#  [[155.56422 ]
#  [183.13734 ]
#  [181.2628  ]
#  [195.13785 ]
#  [141.9785  ]
#  [ 98.510056]]
# 630 Cost 4.097617
# prediction
#  [[155.55571]
#  [183.14159]
#  [181.25877]
#  [195.13597]
#  [141.98378]
#  [ 98.51855]]
# 640 Cost 4.0768
# prediction
#  [[155.54723 ]
#  [183.14583 ]
#  [181.25473 ]
#  [195.13411 ]
#  [141.98907 ]
#  [ 98.526985]]
# 650 Cost 4.056122
# prediction
#  [[155.53877 ]
#  [183.15004 ]
#  [181.25072 ]
#  [195.13226 ]
#  [141.99431 ]
#  [ 98.535416]]
# 660 Cost 4.0356007
# prediction
#  [[155.53036]
#  [183.15425]
#  [181.24675]
#  [195.13043]
#  [141.99957]
#  [ 98.54382]]
# 670 Cost 4.0151715
# prediction
#  [[155.52194]
#  [183.15843]
#  [181.24275]
#  [195.12859]
#  [142.00479]
#  [ 98.55219]]
# 680 Cost 3.9949133
# prediction
#  [[155.51357]
#  [183.16258]
#  [181.23877]
#  [195.12674]
#  [142.01   ]
#  [ 98.56053]]
# 690 Cost 3.974764
# prediction
#  [[155.50522 ]
#  [183.16675 ]
#  [181.2348  ]
#  [195.12491 ]
#  [142.01517 ]
#  [ 98.568855]]
# 700 Cost 3.9547749
# prediction
#  [[155.4969 ]
#  [183.17088]
#  [181.23085]
#  [195.1231 ]
#  [142.02031]
#  [ 98.57713]]
# 710 Cost 3.9348888
# prediction
#  [[155.4886 ]
#  [183.17502]
#  [181.22693]
#  [195.12128]
#  [142.02548]
#  [ 98.5854 ]]
# 720 Cost 3.915189
# prediction
#  [[155.48038]
#  [183.17914]
#  [181.22304]
#  [195.11949]
#  [142.03062]
#  [ 98.59365]]
# 730 Cost 3.8955803
# prediction
#  [[155.47214]
#  [183.18324]
#  [181.21913]
#  [195.11769]
#  [142.0357 ]
#  [ 98.60185]]
# 740 Cost 3.876084
# prediction
#  [[155.46391]
#  [183.18732]
#  [181.21521]
#  [195.11588]
#  [142.04079]
#  [ 98.61004]]
# 750 Cost 3.8567512
# prediction
#  [[155.45573]
#  [183.19139]
#  [181.21135]
#  [195.11409]
#  [142.04587]
#  [ 98.61819]]
# 760 Cost 3.8375378
# prediction
#  [[155.44757]
#  [183.19542]
#  [181.20746]
#  [195.11229]
#  [142.0509 ]
#  [ 98.62631]]
# 770 Cost 3.8184435
# prediction
#  [[155.43947]
#  [183.1995 ]
#  [181.20361]
#  [195.11055]
#  [142.05595]
#  [ 98.63442]]
# 780 Cost 3.799482
# prediction
#  [[155.43137]
#  [183.2035 ]
#  [181.19978]
#  [195.10878]
#  [142.06096]
#  [ 98.64251]]
# 790 Cost 3.7806375
# prediction
#  [[155.42328]
#  [183.20752]
#  [181.19595]
#  [195.10703]
#  [142.06592]
#  [ 98.65054]]
# 800 Cost 3.7619207
# prediction
#  [[155.41524]
#  [183.21153]
#  [181.19214]
#  [195.10527]
#  [142.0709 ]
#  [ 98.65857]]
# 810 Cost 3.743371
# prediction
#  [[155.40726 ]
#  [183.21553 ]
#  [181.18835 ]
#  [195.10355 ]
#  [142.07588 ]
#  [ 98.666565]]
# 820 Cost 3.7248936
# prediction
#  [[155.39925]
#  [183.21948]
#  [181.18454]
#  [195.10178]
#  [142.0808 ]
#  [ 98.67454]]
# 830 Cost 3.7065494
# prediction
#  [[155.39128]
#  [183.22343]
#  [181.18077]
#  [195.10008]
#  [142.08574]
#  [ 98.68248]]
# 840 Cost 3.6883652
# prediction
#  [[155.38338 ]
#  [183.22739 ]
#  [181.17703 ]
#  [195.09834 ]
#  [142.09064 ]
#  [ 98.690414]]
# 850 Cost 3.6702547
# prediction
#  [[155.37546]
#  [183.23134]
#  [181.1733 ]
#  [195.09662]
#  [142.09552]
#  [ 98.6983 ]]
# 860 Cost 3.652296
# prediction
#  [[155.3676  ]
#  [183.23524 ]
#  [181.16956 ]
#  [195.09492 ]
#  [142.10039 ]
#  [ 98.706184]]
# 870 Cost 3.6344316
# prediction
#  [[155.35973 ]
#  [183.23915 ]
#  [181.16583 ]
#  [195.09323 ]
#  [142.10522 ]
#  [ 98.714005]]
# 880 Cost 3.616728
# prediction
#  [[155.35191 ]
#  [183.24303 ]
#  [181.16212 ]
#  [195.0915  ]
#  [142.11006 ]
#  [ 98.721825]]
# 890 Cost 3.5991018
# prediction
#  [[155.34412 ]
#  [183.24692 ]
#  [181.15843 ]
#  [195.08984 ]
#  [142.11488 ]
#  [ 98.729614]]
# 900 Cost 3.5815785
# prediction
#  [[155.33633]
#  [183.2508 ]
#  [181.15472]
#  [195.08815]
#  [142.11966]
#  [ 98.73738]]
# 910 Cost 3.564194
# prediction
#  [[155.32858 ]
#  [183.25462 ]
#  [181.15105 ]
#  [195.08649 ]
#  [142.12444 ]
#  [ 98.745125]]
# 920 Cost 3.5469074
# prediction
#  [[155.32086 ]
#  [183.25848 ]
#  [181.1474  ]
#  [195.08484 ]
#  [142.12921 ]
#  [ 98.752846]]
# 930 Cost 3.529769
# prediction
#  [[155.31317]
#  [183.2623 ]
#  [181.14374]
#  [195.08316]
#  [142.13394]
#  [ 98.76053]]
# 940 Cost 3.512723
# prediction
#  [[155.3055  ]
#  [183.26611 ]
#  [181.14012 ]
#  [195.08151 ]
#  [142.13866 ]
#  [ 98.768196]]
# 950 Cost 3.4958134
# prediction
#  [[155.29788]
#  [183.26993]
#  [181.1365 ]
#  [195.07986]
#  [142.14339]
#  [ 98.77585]]
# 960 Cost 3.478985
# prediction
#  [[155.29022]
#  [183.27368]
#  [181.13287]
#  [195.07819]
#  [142.14807]
#  [ 98.78345]]
# 970 Cost 3.4622972
# prediction
#  [[155.28265 ]
#  [183.27745 ]
#  [181.12929 ]
#  [195.07658 ]
#  [142.15273 ]
#  [ 98.791046]]
# 980 Cost 3.4456885
# prediction
#  [[155.27507]
#  [183.2812 ]
#  [181.12572]
#  [195.07495]
#  [142.15738]
#  [ 98.79862]]
# 990 Cost 3.4292114
# prediction
#  [[155.26752]
#  [183.28496]
#  [181.12213]
#  [195.0733 ]
#  [142.16202]
#  [ 98.80614]]
# 1000 Cost 3.4128363
# prediction
#  [[155.26001]
#  [183.28868]
#  [181.11856]
#  [195.07172]
#  [142.16664]
#  [ 98.81366]]
# 1010 Cost 3.396576
# prediction
#  [[155.25253 ]
#  [183.29239 ]
#  [181.115   ]
#  [195.0701  ]
#  [142.17122 ]
#  [ 98.821175]]
# 1020 Cost 3.3804085
# prediction
#  [[155.24506]
#  [183.29613]
#  [181.11148]
#  [195.06848]
#  [142.17581]
#  [ 98.82863]]
# 1030 Cost 3.3643663
# prediction
#  [[155.23761]
#  [183.29979]
#  [181.10794]
#  [195.0669 ]
#  [142.18039]
#  [ 98.83607]]
# 1040 Cost 3.3484268
# prediction
#  [[155.2302 ]
#  [183.30345]
#  [181.10443]
#  [195.06532]
#  [142.18495]
#  [ 98.84349]]
# 1050 Cost 3.3326094
# prediction
#  [[155.22284]
#  [183.30716]
#  [181.10094]
#  [195.06372]
#  [142.18948]
#  [ 98.85089]]
# 1060 Cost 3.3168724
# prediction
#  [[155.21545 ]
#  [183.31079 ]
#  [181.09744 ]
#  [195.06216 ]
#  [142.194   ]
#  [ 98.858246]]
# 1070 Cost 3.3012583
# prediction
#  [[155.20813]
#  [183.31444]
#  [181.09396]
#  [195.0606 ]
#  [142.19849]
#  [ 98.86559]]
# 1080 Cost 3.2857246
# prediction
#  [[155.2008 ]
#  [183.31807]
#  [181.09052]
#  [195.059  ]
#  [142.20296]
#  [ 98.87293]]
# 1090 Cost 3.270299
# prediction
#  [[155.1935 ]
#  [183.32167]
#  [181.08705]
#  [195.05745]
#  [142.20743]
#  [ 98.88022]]
# 1100 Cost 3.2549648
# prediction
#  [[155.18623 ]
#  [183.32529 ]
#  [181.08362 ]
#  [195.05592 ]
#  [142.21188 ]
#  [ 98.887505]]
# 1110 Cost 3.2397661
# prediction
#  [[155.179  ]
#  [183.32887]
#  [181.08018]
#  [195.05437]
#  [142.21632]
#  [ 98.89475]]
# 1120 Cost 3.2246294
# prediction
#  [[155.17178 ]
#  [183.33246 ]
#  [181.07675 ]
#  [195.05286 ]
#  [142.22075 ]
#  [ 98.901985]]
# 1130 Cost 3.2096376
# prediction
#  [[155.16458]
#  [183.336  ]
#  [181.07335]
#  [195.05128]
#  [142.22513]
#  [ 98.90918]]
# 1140 Cost 3.194725
# prediction
#  [[155.15742]
#  [183.33957]
#  [181.06996]
#  [195.04977]
#  [142.22952]
#  [ 98.91636]]
# 1150 Cost 3.179903
# prediction
#  [[155.15028]
#  [183.34311]
#  [181.06657]
#  [195.04826]
#  [142.23389]
#  [ 98.92352]]
# 1160 Cost 3.1651871
# prediction
#  [[155.14317]
#  [183.34665]
#  [181.0632 ]
#  [195.04675]
#  [142.23824]
#  [ 98.93066]]
# 1170 Cost 3.1505578
# prediction
#  [[155.13605]
#  [183.35013]
#  [181.05983]
#  [195.04523]
#  [142.24257]
#  [ 98.93777]]
# 1180 Cost 3.1360567
# prediction
#  [[155.12898]
#  [183.35362]
#  [181.05647]
#  [195.0437 ]
#  [142.24689]
#  [ 98.94485]]
# 1190 Cost 3.1216233
# prediction
#  [[155.12195]
#  [183.35713]
#  [181.05315]
#  [195.04222]
#  [142.2512 ]
#  [ 98.95193]]
# 1200 Cost 3.1072762
# prediction
#  [[155.1149 ]
#  [183.36061]
#  [181.04984]
#  [195.04073]
#  [142.25548]
#  [ 98.95896]]
# 1210 Cost 3.0930383
# prediction
#  [[155.10791 ]
#  [183.36407 ]
#  [181.04651 ]
#  [195.03925 ]
#  [142.25975 ]
#  [ 98.965996]]
# 1220 Cost 3.078904
# prediction
#  [[155.10095]
#  [183.36754]
#  [181.04321]
#  [195.03778]
#  [142.264  ]
#  [ 98.973  ]]
# 1230 Cost 3.0648346
# prediction
#  [[155.09396 ]
#  [183.37097 ]
#  [181.03992 ]
#  [195.03629 ]
#  [142.26823 ]
#  [ 98.979965]]
# 1240 Cost 3.050883
# prediction
#  [[155.08707]
#  [183.37442]
#  [181.03662]
#  [195.03484]
#  [142.27246]
#  [ 98.98693]]
# 1250 Cost 3.0370026
# prediction
#  [[155.08012 ]
#  [183.37782 ]
#  [181.03336 ]
#  [195.03339 ]
#  [142.27664 ]
#  [ 98.993835]]
# 1260 Cost 3.0232332
# prediction
#  [[155.07324]
#  [183.38123]
#  [181.03009]
#  [195.03192]
#  [142.28085]
#  [ 99.00075]]
# 1270 Cost 3.009547
# prediction
#  [[155.06639]
#  [183.38463]
#  [181.02684]
#  [195.03049]
#  [142.28502]
#  [ 99.00764]]
# 1280 Cost 2.9959576
# prediction
#  [[155.05954]
#  [183.388  ]
#  [181.0236 ]
#  [195.02904]
#  [142.28918]
#  [ 99.01449]]
# 1290 Cost 2.982498
# prediction
#  [[155.05275]
#  [183.39136]
#  [181.02039]
#  [195.02757]
#  [142.29333]
#  [ 99.02133]]
# 1300 Cost 2.9690597
# prediction
#  [[155.04596]
#  [183.39474]
#  [181.01717]
#  [195.02617]
#  [142.29747]
#  [ 99.02815]]
# 1310 Cost 2.9557152
# prediction
#  [[155.03918 ]
#  [183.3981  ]
#  [181.01398 ]
#  [195.02475 ]
#  [142.30157 ]
#  [ 99.034966]]
# 1320 Cost 2.942503
# prediction
#  [[155.03244]
#  [183.40141]
#  [181.01076]
#  [195.02332]
#  [142.30566]
#  [ 99.04172]]
# 1330 Cost 2.9293423
# prediction
#  [[155.02571]
#  [183.40474]
#  [181.00758]
#  [195.02191]
#  [142.30975]
#  [ 99.04848]]
# 1340 Cost 2.9162824
# prediction
#  [[155.01901]
#  [183.40807]
#  [181.00441]
#  [195.0205 ]
#  [142.31381]
#  [ 99.0552 ]]
# 1350 Cost 2.9033086
# prediction
#  [[155.01233 ]
#  [183.41135 ]
#  [181.00124 ]
#  [195.01909 ]
#  [142.31786 ]
#  [ 99.061905]]
# 1360 Cost 2.8904
# prediction
#  [[155.00566 ]
#  [183.41464 ]
#  [180.9981  ]
#  [195.0177  ]
#  [142.3219  ]
#  [ 99.068596]]
# 1370 Cost 2.8775976
# prediction
#  [[154.99902 ]
#  [183.41792 ]
#  [180.99496 ]
#  [195.0163  ]
#  [142.32594 ]
#  [ 99.075264]]
# 1380 Cost 2.8648834
# prediction
#  [[154.99242]
#  [183.42119]
#  [180.99185]
#  [195.01492]
#  [142.32993]
#  [ 99.0819 ]]
# 1390 Cost 2.852246
# prediction
#  [[154.98584]
#  [183.42444]
#  [180.98871]
#  [195.01358]
#  [142.33392]
#  [ 99.08852]]
# 1400 Cost 2.8396902
# prediction
#  [[154.97926]
#  [183.42767]
#  [180.9856 ]
#  [195.01218]
#  [142.33789]
#  [ 99.09512]]
# 1410 Cost 2.8272104
# prediction
#  [[154.97272]
#  [183.43091]
#  [180.98248]
#  [195.0108 ]
#  [142.34186]
#  [ 99.10171]]
# 1420 Cost 2.8148406
# prediction
#  [[154.9662 ]
#  [183.43413]
#  [180.97945]
#  [195.00945]
#  [142.3458 ]
#  [ 99.10827]]
# 1430 Cost 2.8025258
# prediction
#  [[154.95969]
#  [183.43733]
#  [180.97635]
#  [195.00809]
#  [142.34975]
#  [ 99.11479]]
# 1440 Cost 2.790313
# prediction
#  [[154.95323 ]
#  [183.44054 ]
#  [180.97328 ]
#  [195.00674 ]
#  [142.35367 ]
#  [ 99.121315]]
# 1450 Cost 2.7781765
# prediction
#  [[154.94678]
#  [183.44373]
#  [180.97023]
#  [195.00539]
#  [142.35754]
#  [ 99.1278 ]]
# 1460 Cost 2.7660964
# prediction
#  [[154.94034]
#  [183.4469 ]
#  [180.96718]
#  [195.00407]
#  [142.36145]
#  [ 99.13428]]
# 1470 Cost 2.7541044
# prediction
#  [[154.93391]
#  [183.45004]
#  [180.96411]
#  [195.00272]
#  [142.3653 ]
#  [ 99.14073]]
# 1480 Cost 2.7421992
# prediction
#  [[154.92754]
#  [183.45323]
#  [180.96114]
#  [195.00142]
#  [142.36917]
#  [ 99.14716]]
# 1490 Cost 2.7303607
# prediction
#  [[154.92114]
#  [183.45634]
#  [180.95808]
#  [195.00006]
#  [142.37299]
#  [ 99.15357]]
# 1500 Cost 2.7186286
# prediction
#  [[154.91481]
#  [183.45949]
#  [180.95511]
#  [194.99876]
#  [142.37685]
#  [ 99.15996]]
# 1510 Cost 2.7069528
# prediction
#  [[154.90846]
#  [183.46259]
#  [180.9521 ]
#  [194.99742]
#  [142.38066]
#  [ 99.16633]]
# 1520 Cost 2.6953564
# prediction
#  [[154.90219]
#  [183.46574]
#  [180.94914]
#  [194.99615]
#  [142.38448]
#  [ 99.17268]]
# 1530 Cost 2.6838338
# prediction
#  [[154.89589]
#  [183.46881]
#  [180.94614]
#  [194.99484]
#  [142.38824]
#  [ 99.179  ]]
# 1540 Cost 2.6723871
# prediction
#  [[154.88963 ]
#  [183.47191 ]
#  [180.94319 ]
#  [194.99355 ]
#  [142.39201 ]
#  [ 99.185326]]
# 1550 Cost 2.661016
# prediction
#  [[154.88338]
#  [183.47499]
#  [180.94023]
#  [194.99225]
#  [142.39577]
#  [ 99.19159]]
# 1560 Cost 2.6497152
# prediction
#  [[154.87715]
#  [183.47804]
#  [180.93727]
#  [194.99097]
#  [142.3995 ]
#  [ 99.19786]]
# 1570 Cost 2.6384928
# prediction
#  [[154.87093]
#  [183.48108]
#  [180.93436]
#  [194.98967]
#  [142.40321]
#  [ 99.2041 ]]
# 1580 Cost 2.6273477
# prediction
#  [[154.86476]
#  [183.48413]
#  [180.93143]
#  [194.9884 ]
#  [142.40695]
#  [ 99.21034]]
# 1590 Cost 2.6162786
# prediction
#  [[154.85861]
#  [183.48718]
#  [180.92853]
#  [194.98715]
#  [142.41064]
#  [ 99.21654]]
# 1600 Cost 2.6052864
# prediction
#  [[154.85248]
#  [183.4902 ]
#  [180.92563]
#  [194.98587]
#  [142.41434]
#  [ 99.22273]]
# 1610 Cost 2.5943272
# prediction
#  [[154.84633]
#  [183.49321]
#  [180.92271]
#  [194.9846 ]
#  [142.418  ]
#  [ 99.2289 ]]
# 1620 Cost 2.5834992
# prediction
#  [[154.84027 ]
#  [183.49622 ]
#  [180.91985 ]
#  [194.98337 ]
#  [142.42166 ]
#  [ 99.235054]]
# 1630 Cost 2.5726979
# prediction
#  [[154.83418 ]
#  [183.49922 ]
#  [180.91696 ]
#  [194.98213 ]
#  [142.42531 ]
#  [ 99.241165]]
# 1640 Cost 2.5619962
# prediction
#  [[154.82812]
#  [183.50218]
#  [180.91411]
#  [194.98088]
#  [142.42894]
#  [ 99.24728]]
# 1650 Cost 2.5513384
# prediction
#  [[154.82208]
#  [183.50516]
#  [180.91124]
#  [194.97963]
#  [142.43256]
#  [ 99.25337]]
# 1660 Cost 2.5407805
# prediction
#  [[154.81607 ]
#  [183.5081  ]
#  [180.90839 ]
#  [194.97841 ]
#  [142.43614 ]
#  [ 99.259415]]
# 1670 Cost 2.5302584
# prediction
#  [[154.81007 ]
#  [183.51106 ]
#  [180.90556 ]
#  [194.97717 ]
#  [142.43974 ]
#  [ 99.265495]]
# 1680 Cost 2.5198414
# prediction
#  [[154.80411]
#  [183.514  ]
#  [180.90274]
#  [194.97595]
#  [142.44331]
#  [ 99.2715 ]]
# 1690 Cost 2.5094693
# prediction
#  [[154.79816]
#  [183.51694]
#  [180.89992]
#  [194.97473]
#  [142.44687]
#  [ 99.27752]]
# 1700 Cost 2.499151
# prediction
#  [[154.79219]
#  [183.51985]
#  [180.89711]
#  [194.97351]
#  [142.45042]
#  [ 99.2835 ]]
# 1710 Cost 2.4889195
# prediction
#  [[154.78629]
#  [183.52275]
#  [180.89432]
#  [194.97234]
#  [142.45398]
#  [ 99.28948]]
# 1720 Cost 2.4787621
# prediction
#  [[154.7804 ]
#  [183.52563]
#  [180.89153]
#  [194.97113]
#  [142.45747]
#  [ 99.29543]]
# 1730 Cost 2.4686453
# prediction
#  [[154.7745 ]
#  [183.52855]
#  [180.88876]
#  [194.96992]
#  [142.461  ]
#  [ 99.30137]]
# 1740 Cost 2.4586165
# prediction
#  [[154.76866 ]
#  [183.53143 ]
#  [180.88599 ]
#  [194.96875 ]
#  [142.4645  ]
#  [ 99.307274]]
# 1750 Cost 2.4486587
# prediction
#  [[154.76283]
#  [183.5343 ]
#  [180.88322]
#  [194.96754]
#  [142.46797]
#  [ 99.31317]]
# 1760 Cost 2.4387467
# prediction
#  [[154.757   ]
#  [183.53716 ]
#  [180.88046 ]
#  [194.96635 ]
#  [142.47144 ]
#  [ 99.319046]]
# 1770 Cost 2.4289112
# prediction
#  [[154.7512 ]
#  [183.54   ]
#  [180.87773]
#  [194.9652 ]
#  [142.47488]
#  [ 99.3249 ]]
# 1780 Cost 2.4191496
# prediction
#  [[154.74544 ]
#  [183.54283 ]
#  [180.875   ]
#  [194.96402 ]
#  [142.47833 ]
#  [ 99.330734]]
# 1790 Cost 2.4094121
# prediction
#  [[154.73965 ]
#  [183.54567 ]
#  [180.87227 ]
#  [194.96284 ]
#  [142.48177 ]
#  [ 99.336555]]
# 1800 Cost 2.3997746
# prediction
#  [[154.73392 ]
#  [183.54848 ]
#  [180.86957 ]
#  [194.96169 ]
#  [142.48517 ]
#  [ 99.342354]]
# 1810 Cost 2.3902016
# prediction
#  [[154.7282 ]
#  [183.55128]
#  [180.86687]
#  [194.96053]
#  [142.48859]
#  [ 99.34812]]
# 1820 Cost 2.38069
# prediction
#  [[154.7225 ]
#  [183.55408]
#  [180.86417]
#  [194.95937]
#  [142.49197]
#  [ 99.35389]]
# 1830 Cost 2.3712134
# prediction
#  [[154.71681 ]
#  [183.55687 ]
#  [180.86148 ]
#  [194.95824 ]
#  [142.49535 ]
#  [ 99.359634]]
# 1840 Cost 2.3618376
# prediction
#  [[154.71117]
#  [183.55963]
#  [180.85881]
#  [194.95709]
#  [142.49872]
#  [ 99.36537]]
# 1850 Cost 2.3524988
# prediction
#  [[154.70552]
#  [183.56241]
#  [180.85614]
#  [194.95595]
#  [142.50204]
#  [ 99.37107]]
# 1860 Cost 2.343205
# prediction
#  [[154.69989]
#  [183.56519]
#  [180.85347]
#  [194.95482]
#  [142.50539]
#  [ 99.37676]]
# 1870 Cost 2.3340049
# prediction
#  [[154.69429]
#  [183.56793]
#  [180.85083]
#  [194.95369]
#  [142.50873]
#  [ 99.38243]]
# 1880 Cost 2.3248506
# prediction
#  [[154.6887 ]
#  [183.57066]
#  [180.84818]
#  [194.95258]
#  [142.51202]
#  [ 99.38808]]
# 1890 Cost 2.3157444
# prediction
#  [[154.68312]
#  [183.5734 ]
#  [180.84557]
#  [194.95145]
#  [142.51532]
#  [ 99.39372]]
# 1900 Cost 2.3067434
# prediction
#  [[154.6776 ]
#  [183.57611]
#  [180.84296]
#  [194.95033]
#  [142.51863]
#  [ 99.39934]]
# 1910 Cost 2.2977583
# prediction
#  [[154.67204 ]
#  [183.57881 ]
#  [180.84032 ]
#  [194.9492  ]
#  [142.52188 ]
#  [ 99.404915]]
# 1920 Cost 2.2888234
# prediction
#  [[154.66652]
#  [183.58153]
#  [180.83772]
#  [194.9481 ]
#  [142.52515]
#  [ 99.4105 ]]
# 1930 Cost 2.2799714
# prediction
#  [[154.66104]
#  [183.58421]
#  [180.83513]
#  [194.94702]
#  [142.52841]
#  [ 99.41608]]
# 1940 Cost 2.2711742
# prediction
#  [[154.65556]
#  [183.58688]
#  [180.83253]
#  [194.9459 ]
#  [142.53163]
#  [ 99.42162]]
# 1950 Cost 2.2624376
# prediction
#  [[154.65012]
#  [183.58957]
#  [180.82996]
#  [194.94482]
#  [142.53487]
#  [ 99.42714]]
# 1960 Cost 2.2537298
# prediction
#  [[154.64468]
#  [183.59225]
#  [180.8274 ]
#  [194.94377]
#  [142.53809]
#  [ 99.43266]]
# 1970 Cost 2.2451003
# prediction
#  [[154.63924]
#  [183.59488]
#  [180.82483]
#  [194.94267]
#  [142.54128]
#  [ 99.43814]]
# 1980 Cost 2.2365339
# prediction
#  [[154.63385]
#  [183.59753]
#  [180.82228]
#  [194.94159]
#  [142.54445]
#  [ 99.44362]]
# 1990 Cost 2.228008
# prediction
#  [[154.62845 ]
#  [183.60016 ]
#  [180.81972 ]
#  [194.9405  ]
#  [142.54762 ]
#  [ 99.449066]]
# 2000 Cost 2.2195597
# prediction
#  [[154.6231 ]
#  [183.60277]
#  [180.81718]
#  [194.93945]
#  [142.55078]
#  [ 99.4545 ]]

# %% [markdown]
# * ask me score

# %%
print('Your score will be ', sess.run(hypothesis, feed_dict={X:[[100,70,101]]}))
# Out:
# Your score will be  [[171.08965]]

# %%
print('other score will be ', sess.run(hypothesis, feed_dict={X:[[60,70,100],[90,100,80]]}))
# Out:
# other score will be  [[111.77626]
#  [198.40393]]

# %% [markdown]
# *************************************************************

# %% [markdown]
# *************************************************************

# %%
import tensorflow as tf
tf.set_random_seed(777)

# %%
filename_queue = tf.train.string_input_producer(
    ['data-01-test-score.csv'], shuffle=False, name='filename_queue')

# %%
reader = tf.TextLineReader()
key, value = reader.read(filename_queue)

# %% [markdown]
# * default values, in case of empty columns. also specifies the type if the
# * decoded result

# %%
record_defaults = [[0.],[0.],[0.],[0.]]
xy = tf.decode_csv(value, record_defaults=record_defaults)

# %% [markdown]
# * collect batches of csv in

# %%
train_x_batch, train_y_batch = \
tf.train.batch([xy[0:-1], xy[-1:]], batch_size=10)

# %% [markdown]
# * placeholders for a tensor that will be always fed

# %%
X = tf.placeholder(tf.float32, shape=[None,3])
Y = tf.placeholder(tf.float32, shape=[None,1])

W = tf.Variable(tf.random_normal([3,1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# %% [markdown]
# * hypothesis

# %%
hypothesis = tf.matmul(X,W)+b

# %% [markdown]
# * simplified cost/ Loss function

# %%
cost = tf.reduce_mean(tf.square(hypothesis -Y))

# %% [markdown]
# * minimizer

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# %% [markdown]
# * launch the graph in a session

# %%
sess = tf.Session()

# %% [markdown]
# * Intrializes global variable in the graph

# %%
sess.run(tf.global_variables_initializer())

# %% [markdown]
# * start populating filename queue

# %%
coord = tf.train.Coordinator()
threads = tf.train.start_queue_runners(sess=sess, coord=coord)
# Out:
# INFO:tensorflow:Error reported to Coordinator: <class 'tensorflow.python.framework.errors_impl.CancelledError'>, FIFOQueue '_7_batch/fifo_queue' is closed.
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT, DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, batch/packed, batch/packed_1)]]

# %%
for step in range(2001):
    x_batch, y_batch = sess.run([train_x_batch, train_y_batch])
    cost_val, hy_val, _= sess.run(
        [cost, hypothesis, train],
        feed_dict={X:x_batch, Y:y_batch})
    if step % 10 ==0:
        print(step, 'Cost: ', cost_val, '\nprediction:\n', hy_val)
        
coord.request_stop()
coord.join(threads)
# Out:
# ---------------------------------------------------------------------------
# OutOfRangeError                           Traceback (most recent call last)
# D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#
# D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#
# D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\framework\errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     472             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 473             c_api.TF_GetCode(self.status.status))
#     474     # Delete the underlying status object from memory otherwise it stays alive
#
# OutOfRangeError: FIFOQueue '_15_batch_2/fifo_queue' is closed and has insufficient elements (requested 10, current size 0)
# 	 [[Node: batch_2 = QueueDequeueManyV2[component_types=[DT_FLOAT, DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch_2/fifo_queue, batch_2/n)]]
#
# During handling of the above exception, another exception occurred:
#
# OutOfRangeError                           Traceback (most recent call last)
# <ipython-input-42-59dda47dc426> in <module>
#       1 for step in range(2001):
# ----> 2     x_batch, y_batch = sess.run([train_x_batch, train_y_batch])
#       3     cost_val, hy_val, _= sess.run(
#       4         [cost, hypothesis, train],
#       5         feed_dict={X:x_batch, Y:y_batch})
#
# D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1361         except KeyError:
#    1362           pass
# -> 1363       raise type(e)(node_def, op, message)
#    1364
#    1365   def _extend_graph(self):
#
# OutOfRangeError: FIFOQueue '_15_batch_2/fifo_queue' is closed and has insufficient elements (requested 10, current size 0)
# 	 [[Node: batch_2 = QueueDequeueManyV2[component_types=[DT_FLOAT, DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch_2/fifo_queue, batch_2/n)]]
#
# Caused by op 'batch_2', defined at:
#   File "D:\anaconda\envs\chch4934\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "D:\anaconda\envs\chch4934\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "D:\anaconda\envs\chch4934\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
#   File "D:\anaconda\envs\chch4934\lib\site-packages\ipykernel\kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tornado\platform\asyncio.py", line 153, in start
#     self.asyncio_loop.run_forever()
#   File "D:\anaconda\envs\chch4934\lib\asyncio\base_events.py", line 442, in run_forever
#     self._run_once()
#   File "D:\anaconda\envs\chch4934\lib\asyncio\base_events.py", line 1462, in _run_once
#     handle._run()
#   File "D:\anaconda\envs\chch4934\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tornado\gen.py", line 787, in inner
#     self.run()
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tornado\gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\ipykernel\kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\ipykernel\kernelbase.py", line 541, in execute_request
#     user_expressions, allow_stdin,
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\ipykernel\ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\IPython\core\interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\IPython\core\interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\IPython\core\interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\IPython\core\interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "D:\anaconda\envs\chch4934\lib\site-packages\IPython\core\interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-41-cd136a6db988>", line 20, in <module>
#     tf.train.batch([xy[0:-1], xy[-1:]], batch_size=10)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\training\input.py", line 979, in batch
#     name=name)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\training\input.py", line 754, in _batch
#     dequeued = queue.dequeue_many(batch_size, name=name)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\ops\data_flow_ops.py", line 475, in dequeue_many
#     self._queue_ref, n=n, component_types=self._dtypes, name=name)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\ops\gen_data_flow_ops.py", line 2764, in _queue_dequeue_many_v2
#     component_types=component_types, timeout_ms=timeout_ms, name=name)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\framework\ops.py", line 3160, in create_op
#     op_def=op_def)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\framework\ops.py", line 1625, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# OutOfRangeError (see above for traceback): FIFOQueue '_15_batch_2/fifo_queue' is closed and has insufficient elements (requested 10, current size 0)
# 	 [[Node: batch_2 = QueueDequeueManyV2[component_types=[DT_FLOAT, DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch_2/fifo_queue, batch_2/n)]]

# %%
# Lab 4 Multi-variable linear regression
# https://www.tensorflow.org/programmers_guide/reading_data

import tensorflow as tf
tf.set_random_seed(777)  # for reproducibility

filename_queue = tf.train.string_input_producer(
    ['data-01-test-score.csv'], shuffle=False, name='filename_queue')

reader = tf.TextLineReader()
key, value = reader.read(filename_queue)

# Default values, in case of empty columns. Also specifies the type of the
# decoded result.
record_defaults = [[0.], [0.], [0.], [0.]]
xy = tf.decode_csv(value, record_defaults=record_defaults)

# collect batches of csv in
train_x_batch, train_y_batch = \
    tf.train.batch([xy[0:-1], xy[-1:]], batch_size=10)

# placeholders for a tensor that will be always fed.
X = tf.placeholder(tf.float32, shape=[None, 3])
Y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([3, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# Hypothesis
hypothesis = tf.matmul(X, W) + b

# Simplified cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

# Start populating the filename queue.
coord = tf.train.Coordinator()
threads = tf.train.start_queue_runners(sess=sess, coord=coord)

for step in range(2001):
    x_batch, y_batch = sess.run([train_x_batch, train_y_batch])
    cost_val, hy_val, _ = sess.run(
        [cost, hypothesis, train], feed_dict={X: x_batch, Y: y_batch})
    if step % 10 == 0:
        print(step, "Cost: ", cost_val, "\nPrediction:\n", hy_val)

coord.request_stop()
coord.join(threads)

# Ask my score
print("Your score will be ",
      sess.run(hypothesis, feed_dict={X: [[100, 70, 101]]}))

print("Other scores will be ",
      sess.run(hypothesis, feed_dict={X: [[60, 70, 110], [90, 100, 80]]}))
# Out:
# INFO:tensorflow:Error reported to Coordinator: <class 'tensorflow.python.framework.errors_impl.InvalidArgumentError'>, Field 0 in record 0 is not a valid float: # EXAM1
# 	 [[Node: DecodeCSV = DecodeCSV[OUT_TYPE=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], field_delim=",", na_value="", use_quote_delim=true, _device="/job:localhost/replica:0/task:0/device:CPU:0"](ReaderReadV2:1, DecodeCSV/record_defaults_0, DecodeCSV/record_defaults_0, DecodeCSV/record_defaults_0, DecodeCSV/record_defaults_0)]]
# ---------------------------------------------------------------------------
# OutOfRangeError                           Traceback (most recent call last)
# D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#
# D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#
# D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\framework\errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     472             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 473             c_api.TF_GetCode(self.status.status))
#     474     # Delete the underlying status object from memory otherwise it stays alive
#
# OutOfRangeError: FIFOQueue '_15_batch_2/fifo_queue' is closed and has insufficient elements (requested 10, current size 0)
# 	 [[Node: batch_2 = QueueDequeueManyV2[component_types=[DT_FLOAT, DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch_2/fifo_queue, batch_2/n)]]
#
# During handling of the above exception, another exception occurred:
#
# OutOfRangeError                           Traceback (most recent call last)
# <ipython-input-41-cd136a6db988> in <module>
#      47
#      48 for step in range(2001):
# ---> 49     x_batch, y_batch = sess.run([train_x_batch, train_y_batch])
#      50     cost_val, hy_val, _ = sess.run(
#      51         [cost, hypothesis, train], feed_dict={X: x_batch, Y: y_batch})
#
# D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1361         except KeyError:
#    1362           pass
# -> 1363       raise type(e)(node_def, op, message)
#    1364
#    1365   def _extend_graph(self):
#
# OutOfRangeError: FIFOQueue '_15_batch_2/fifo_queue' is closed and has insufficient elements (requested 10, current size 0)
# 	 [[Node: batch_2 = QueueDequeueManyV2[component_types=[DT_FLOAT, DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch_2/fifo_queue, batch_2/n)]]
#
# Caused by op 'batch_2', defined at:
#   File "D:\anaconda\envs\chch4934\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "D:\anaconda\envs\chch4934\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "D:\anaconda\envs\chch4934\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
#   File "D:\anaconda\envs\chch4934\lib\site-packages\ipykernel\kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tornado\platform\asyncio.py", line 153, in start
#     self.asyncio_loop.run_forever()
#   File "D:\anaconda\envs\chch4934\lib\asyncio\base_events.py", line 442, in run_forever
#     self._run_once()
#   File "D:\anaconda\envs\chch4934\lib\asyncio\base_events.py", line 1462, in _run_once
#     handle._run()
#   File "D:\anaconda\envs\chch4934\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tornado\gen.py", line 787, in inner
#     self.run()
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tornado\gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\ipykernel\kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\ipykernel\kernelbase.py", line 541, in execute_request
#     user_expressions, allow_stdin,
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\ipykernel\ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\IPython\core\interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\IPython\core\interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\IPython\core\interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\IPython\core\interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "D:\anaconda\envs\chch4934\lib\site-packages\IPython\core\interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-41-cd136a6db988>", line 20, in <module>
#     tf.train.batch([xy[0:-1], xy[-1:]], batch_size=10)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\training\input.py", line 979, in batch
#     name=name)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\training\input.py", line 754, in _batch
#     dequeued = queue.dequeue_many(batch_size, name=name)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\ops\data_flow_ops.py", line 475, in dequeue_many
#     self._queue_ref, n=n, component_types=self._dtypes, name=name)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\ops\gen_data_flow_ops.py", line 2764, in _queue_dequeue_many_v2
#     component_types=component_types, timeout_ms=timeout_ms, name=name)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\framework\ops.py", line 3160, in create_op
#     op_def=op_def)
#   File "D:\anaconda\envs\chch4934\lib\site-packages\tensorflow\python\framework\ops.py", line 1625, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# OutOfRangeError (see above for traceback): FIFOQueue '_15_batch_2/fifo_queue' is closed and has insufficient elements (requested 10, current size 0)
# 	 [[Node: batch_2 = QueueDequeueManyV2[component_types=[DT_FLOAT, DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch_2/fifo_queue, batch_2/n)]]
